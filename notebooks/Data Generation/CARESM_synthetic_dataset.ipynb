# %% [markdown]
# # Transformation of tabular dataset into CARE-SM RDF data

# %%
import pandas as pd
import numpy as np
import joblib
import re
import uuid
from rdflib import ConjunctiveGraph
from string import Template
from itertools import accumulate
from scipy.stats import norm, genextreme, exponweib
from datetime import datetime, date, timedelta

# %%
df = pd.read_csv('./syn_data.csv', index_col=0)
df
# Out:
#       hospital_stay_length        gcs     nb_acte  gender  entry  output  \
# 0                41.089445  17.086233   34.307297       0      0     0.0
# 1                21.702298  18.805639  133.523169       0      1     1.0
# 2                 4.627752  19.516216   85.648533       0      2     0.0
# 3                12.830087  19.940518   17.982208       1      1     2.0
# 4                75.675201  21.665547  132.859962       0      3     1.0
# ...                    ...        ...         ...     ...    ...     ...
# 9995             23.668646  18.302874   41.950003       1      5     2.0
# 9996             33.643450  20.634914   84.554423       0      1     1.0
# 9997             18.122234  15.604823    4.792264       1      5     2.0
# 9998             43.964242  18.368290    4.802513       1      2     1.0
# 9999             19.324875  19.904317  103.597895       0      5     1.0
#
#       entry_code  ica  ttt  ica_therapy  ...  ivh        age  nimodipine  \
# 0              0    0    0            0  ...    0  38.712762          -1
# 1              2    2    1            0  ...    0  58.565461          89
# 2              1    2    2            0  ...    1  76.432889          12
# 3              3    4    2            0  ...    1  87.351874          29
# 4              4    5    2            0  ...    0  75.440254          26
# ...          ...  ...  ...          ...  ...  ...        ...         ...
# 9995           3    3    2            0  ...    1  83.381334          22
# 9996           1    5    1            0  ...    0  49.631746          -1
# 9997           1    6    1            0  ...    0  53.602286          24
# 9998           1    3    2            0  ...    1  82.388699          26
# 9999           0    6    1            0  ...    0  43.675937          75
#
#       paracetamol  nad  corotrop  morphine  dve  atl  iot
# 0              -1   -1        -1        -1   -1   -1   25
# 1              58   26        -1        -1  116   -1   -1
# 2              -1   -1        -1        -1   40   -1   -1
# 3              -1   -1        -1        -1   -1   -1   53
# 4              -1   -1        -1        -1   79   -1   52
# ...           ...  ...       ...       ...  ...  ...  ...
# 9995           -1   -1        -1        -1   -1   -1   40
# 9996           -1   -1        -1        -1   24   -1   56
# 9997           -1   -1        -1        -1   -1   -1   55
# 9998           -1   -1        -1        -1   -1   -1   48
# 9999           46   -1        -1        -1   -1   -1   23
#
# [10000 rows x 31 columns]

# %%
size_train = int(len(df) * 0.8)

# %%
numerical = ['hospital_stay_length', 'gcs', 'nb_acte', 'age']
categorical = ['gender', 'entry', 'entry_code', 'ica', 'ttt', 'ica_therapy', 'fever', 'o2_clinic', 'o2', 'hta', 'hct', 'tabagisme', 'etOH', 'diabete', 'headache', 'instable', 'vasospasme', 'ivh']
events = ['nimodipine',  'paracetamol', 'nad', 'corotrop', 'morphine', 'dve', 'atl', 'iot']

events_codes = {
    'nimodipine': 'C08CA06', # ACT
    'paracetamol': 'N02BE01', # ACT
    'nad': 'C01CA03', # ACT
    'corotrop': 'C01CE02', # ACT
    'morphine': 'N02AA01', # ACT
    'dve': '00P6X0Z', # Removal of Drainage Device from Cerebral Ventricle External Approach (ICD-10)
    'atl': 'Z98.6', # ICD-10
    'iot': '0BH17EZ' # ICD-10
}

#['hospital_stay_length', 'gcs', 'nb_acte', 'age']
#['gender', 'entry', 'entry_code', 'ica', 'ttt', 'ica_therapy', 'fever', 'o2_clinic', 'o2', 'hta', 'hct', 'tabagisme', 'etOH', 'diabete', 'headache', 'instable', 'vasospasme', 'ivh']
other_codes = {
    'hospital_stay_length': '1', 
    'gcs':'2', 
    'nb_acte':'3', 
    'age':'4',
    'gender':'5',
    'entry':'6',
    'entry_code':'7',
    'ica':'8',
    'ttt':'9',
    'ica_therapy':'10',
    'fever':'11',
    'o2_clinic':'12',
    'o2':'13',
    'hta':'14',
    'hct':'15',
    'tabagisme':'16',
    'etOH':'17',
    'diabete':'18',
    'headache':'19',
    'instable':'20',
    'vasospasme':'21',
    'ivh':'22'
}

# %%
prefix  = """   
@prefix sio: <http://semanticscience.org/resource/> .
@prefix ncit: <http://purl.obolibrary.org/obo/NCIT_> .
@prefix nvasc: <http://nvasc.org/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
"""

caresm_diagnosis_code_date_template = Template("""
    nvasc:context_$context_id {                                           
        nvasc:synth_patient_$patient_id a sio:Person ;
            sio:has-role nvasc:role_$patient_id .
        nvasc:role_$patient_id a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
            sio:is-realized-in nvasc:diag_$diag_id .
            
        nvasc:diag_$diag_id a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
            sio:has-output nvasc:diag_output_$diag_out_id .
            
        nvasc:diag_output_$diag_out_id a sio:InformationContentEntity, 
            ncit:$diag_code. 
    }
    
    {
        nvasc:context_$context_id sio:SIO_000680 "$diag_start_date"^^xsd:dateTime ;
                              sio:SIO_000681 "$diag_end_date"^^xsd:dateTime ;
                              sio:SIO_000068 nvasc:timeline_$patient_id . # part-of 
                              
        nvasc:timeline_$patient_id a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
                                sio:SIO_000332 nvasc:synth_patient_$patient_id ; # is-about
                                sio:SIO_000028 nvasc:context_$context_id . # this is a materialization of the has-part property
    }
    """)

caresm_diagnosis_code_template = Template("""
    nvasc:synth_patient_$patient_id a sio:Person ;
        sio:has-role nvasc:role_$patient_id .
    nvasc:role_$patient_id a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
        sio:is-realized-in nvasc:diag_$diag_id .
        
    nvasc:diag_$diag_id a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
        sio:has-output nvasc:diag_output_$diag_out_id .
        
    nvasc:diag_output_$diag_out_id a sio:InformationContentEntity, 
        ncit:$diag_code. 
    """)
    
caresm_diagnosis_quantity_template = Template("""
    nvasc:synth_patient_$patient_id a sio:Person ;
        sio:has-role nvasc:role_$patient_id .
    nvasc:role_$patient_id a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
        sio:is-realized-in nvasc:diag_$diag_id .
        
    nvasc:diag_$diag_id a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
        sio:has-output nvasc:diag_output_$diag_out_id .
        
    nvasc:diag_output_$diag_out_id a sio:InformationContentEntity, 
        ncit:$diag_code ; # TODO should be a proper dereferenceable URI
        sio:has-value "$diag_value"^^xsd:float ;
        sio:has-unit  "$diag_unit" . # TODO should be a URI, subClassOf sio:Unit
    """)

def gen_start_event(y_min=2020, y_max=2023):
    n_days = (y_max - y_min) * 365
    d0 = datetime.fromisoformat(f"{y_min}-01-01")
    day_rand = round(np.random.uniform(n_days))
    delta = timedelta(days=day_rand, hours=round(norm.rvs(12, 5)), minutes=round(np.random.uniform(60)))
    d_out = d0 + delta
    return(d_out)


def gen_patient_rdf(row, kg):
    _i = row.name
    d_start = gen_start_event()
    for f in row.index:
        if f in events:
            if row[f] != -1:
                h = row[f]
                d_event = d_start + timedelta(hours=h)
                diag_label = f
                diag_code = events_codes[f]
                rdf = caresm_diagnosis_code_date_template.substitute(diag_id=uuid.uuid4(),
                                                        diag_out_id=uuid.uuid4(),
                                                        context_id=uuid.uuid4(),
                                                        diag_label = f,
                                                        diag_code = events_codes[f],
                                                        diag_start_date = d_start.isoformat(),
                                                        diag_end_date = d_event.isoformat(),
                                                        patient_id = _i)
                print(row[f])
                print(d_start)
                print(rdf)
                kg.parse(data=prefix+rdf, format="trig")
        
        elif f in numerical:
            value = None
            unit = None 
            if f == "hospital_stay_length":
                value = round(row[f])
                unit = "days"
            elif  f == "gcs":
                value = round(row[f],2)
                unit = "gcs"
            elif  f == "nb_acte":
                value = round(row[f])
                unit = "received medical treatments"
            elif  f == "age":
                value = round(row[f])
                unit = "age"
            
            rdf = caresm_diagnosis_quantity_template.substitute(
                diag_id=uuid.uuid4(), 
                diag_out_id=uuid.uuid4(),
                diag_label=f,  
                diag_code=str(f) + "_" + str(row[f]),
                diag_value=value, 
                diag_unit=unit, 
                patient_id=_i)
            kg.parse(data=prefix+rdf, format="trig")
            
        # ['gender', 'entry', 'entry_code', 'ica', 'ttt', 'ica_therapy', 'fever', 'o2_clinic', 'o2', 'hta', 'hct', 'tabagisme', 'etOH', 'diabete', 'headache', 'instable', 'vasospasme', 'ivh']
        elif f in categorical:
             diag_label = f
             diag_code = row[f]
             rdf = caresm_diagnosis_code_template.substitute(
                diag_id=uuid.uuid4(), 
                diag_out_id=uuid.uuid4(),
                diag_label=f, 
                diag_code=str(f) + "_" + str(row[f]), 
                patient_id=_i)
        
             kg.parse(data=prefix+rdf, format="trig")

# %%
date_entrance = gen_start_event()
print(date_entrance)
date_2 = date_entrance + timedelta(hours=36)
print(date_2)
# Out:
# 2022-06-09 12:20:00
# 2022-06-11 00:20:00

# %%
kg = ConjunctiveGraph()
test_df = df.head(100)
# print(test_df)
test_df.apply(gen_patient_rdf, axis=1, kg = kg)
print(f"Generated {len(kg)} RDF triples")
kg.serialize("caresm.trig", format="trig")
kg.serialize("caresm.nq", format="nquads")
# Out:
# 25.0
# 2020-11-25 15:45:00
#
#     nvasc:context_416e9f40-89b3-4abf-a231-8e6ee77a38f2 {
#         nvasc:synth_patient_0 a sio:Person ;
#             sio:has-role nvasc:role_0 .
#         nvasc:role_0 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_58110405-81bb-42b9-892b-bc6c36757cc3 .
#
#         nvasc:diag_58110405-81bb-42b9-892b-bc6c36757cc3 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_7854b421-942b-4a7e-a4ba-e7fb96d65d1c .
#
#         nvasc:diag_output_7854b421-942b-4a7e-a4ba-e7fb96d65d1c a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_416e9f40-89b3-4abf-a231-8e6ee77a38f2 sio:SIO_000680 "2020-11-25T15:45:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-11-26T16:45:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_0 . # part-of
#
#         nvasc:timeline_0 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_0 ; # is-about
#                                 sio:SIO_000028 nvasc:context_416e9f40-89b3-4abf-a231-8e6ee77a38f2 . # this is a materialization of the has-part property
#     }
#
# 89.0
# 2021-12-31 14:39:00
#
#     nvasc:context_27ca28c1-6fd8-4d35-b7be-3f2828dfddf8 {
#         nvasc:synth_patient_1 a sio:Person ;
#             sio:has-role nvasc:role_1 .
#         nvasc:role_1 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_3ce2954f-fa20-4e2a-9f8a-6d7445f5242e .
#
#         nvasc:diag_3ce2954f-fa20-4e2a-9f8a-6d7445f5242e a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_b4eb116a-5bbe-4106-b58f-1f3a621ddbec .
#
#         nvasc:diag_output_b4eb116a-5bbe-4106-b58f-1f3a621ddbec a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_27ca28c1-6fd8-4d35-b7be-3f2828dfddf8 sio:SIO_000680 "2021-12-31T14:39:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-01-04T07:39:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_1 . # part-of
#
#         nvasc:timeline_1 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_1 ; # is-about
#                                 sio:SIO_000028 nvasc:context_27ca28c1-6fd8-4d35-b7be-3f2828dfddf8 . # this is a materialization of the has-part property
#     }
#
# 58.0
# 2021-12-31 14:39:00
#
#     nvasc:context_081bd6d0-f7b0-4964-a2a6-f4150d9d7836 {
#         nvasc:synth_patient_1 a sio:Person ;
#             sio:has-role nvasc:role_1 .
#         nvasc:role_1 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_013e087c-8122-4501-8768-3a92562b22a7 .
#
#         nvasc:diag_013e087c-8122-4501-8768-3a92562b22a7 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_7d72c096-1dce-4caf-b588-164df3b8d72a .
#
#         nvasc:diag_output_7d72c096-1dce-4caf-b588-164df3b8d72a a sio:InformationContentEntity,
#             ncit:N02BE01.
#     }
#
#     {
#         nvasc:context_081bd6d0-f7b0-4964-a2a6-f4150d9d7836 sio:SIO_000680 "2021-12-31T14:39:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-01-03T00:39:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_1 . # part-of
#
#         nvasc:timeline_1 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_1 ; # is-about
#                                 sio:SIO_000028 nvasc:context_081bd6d0-f7b0-4964-a2a6-f4150d9d7836 . # this is a materialization of the has-part property
#     }
#
# 26.0
# 2021-12-31 14:39:00
#
#     nvasc:context_47440b0c-9368-4d5a-890a-5f8c2323a523 {
#         nvasc:synth_patient_1 a sio:Person ;
#             sio:has-role nvasc:role_1 .
#         nvasc:role_1 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_248b32b1-d28d-4da3-b372-39bfd393086b .
#
#         nvasc:diag_248b32b1-d28d-4da3-b372-39bfd393086b a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_9d1ffc87-29d3-4e8d-a2aa-7ff4d6225764 .
#
#         nvasc:diag_output_9d1ffc87-29d3-4e8d-a2aa-7ff4d6225764 a sio:InformationContentEntity,
#             ncit:C01CA03.
#     }
#
#     {
#         nvasc:context_47440b0c-9368-4d5a-890a-5f8c2323a523 sio:SIO_000680 "2021-12-31T14:39:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-01-01T16:39:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_1 . # part-of
#
#         nvasc:timeline_1 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_1 ; # is-about
#                                 sio:SIO_000028 nvasc:context_47440b0c-9368-4d5a-890a-5f8c2323a523 . # this is a materialization of the has-part property
#     }
#
# 116.0
# 2021-12-31 14:39:00
#
#     nvasc:context_f19c4fc5-d5ac-46f6-b5c4-ce9f9e4b21e3 {
#         nvasc:synth_patient_1 a sio:Person ;
#             sio:has-role nvasc:role_1 .
#         nvasc:role_1 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_ecf990e0-8a2c-4d63-9999-40bde7a7ccf0 .
#
#         nvasc:diag_ecf990e0-8a2c-4d63-9999-40bde7a7ccf0 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_d7caebb8-d7fe-48e2-99ca-e47ac8df3afc .
#
#         nvasc:diag_output_d7caebb8-d7fe-48e2-99ca-e47ac8df3afc a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_f19c4fc5-d5ac-46f6-b5c4-ce9f9e4b21e3 sio:SIO_000680 "2021-12-31T14:39:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-01-05T10:39:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_1 . # part-of
#
#         nvasc:timeline_1 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_1 ; # is-about
#                                 sio:SIO_000028 nvasc:context_f19c4fc5-d5ac-46f6-b5c4-ce9f9e4b21e3 . # this is a materialization of the has-part property
#     }
#
# 12.0
# 2020-10-15 12:52:00
#
#     nvasc:context_915bbe75-3aad-44f7-a9a4-5fb1f49b58c7 {
#         nvasc:synth_patient_2 a sio:Person ;
#             sio:has-role nvasc:role_2 .
#         nvasc:role_2 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_9cf1c7c4-d1d1-466c-adce-72e67495ff70 .
#
#         nvasc:diag_9cf1c7c4-d1d1-466c-adce-72e67495ff70 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_7bc4392b-e521-4d02-b899-6e3b5dea99f8 .
#
#         nvasc:diag_output_7bc4392b-e521-4d02-b899-6e3b5dea99f8 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_915bbe75-3aad-44f7-a9a4-5fb1f49b58c7 sio:SIO_000680 "2020-10-15T12:52:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-10-16T00:52:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_2 . # part-of
#
#         nvasc:timeline_2 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_2 ; # is-about
#                                 sio:SIO_000028 nvasc:context_915bbe75-3aad-44f7-a9a4-5fb1f49b58c7 . # this is a materialization of the has-part property
#     }
#
# 40.0
# 2020-10-15 12:52:00
#
#     nvasc:context_4d4d9f40-a7cb-4979-8a9e-ed296d049137 {
#         nvasc:synth_patient_2 a sio:Person ;
#             sio:has-role nvasc:role_2 .
#         nvasc:role_2 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_8ab1e83b-7c77-4508-9ca7-fb259e36796e .
#
#         nvasc:diag_8ab1e83b-7c77-4508-9ca7-fb259e36796e a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_db0f1e1b-ff0f-4309-a81c-f1af7def885a .
#
#         nvasc:diag_output_db0f1e1b-ff0f-4309-a81c-f1af7def885a a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_4d4d9f40-a7cb-4979-8a9e-ed296d049137 sio:SIO_000680 "2020-10-15T12:52:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-10-17T04:52:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_2 . # part-of
#
#         nvasc:timeline_2 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_2 ; # is-about
#                                 sio:SIO_000028 nvasc:context_4d4d9f40-a7cb-4979-8a9e-ed296d049137 . # this is a materialization of the has-part property
#     }
#
# 29.0
# 2022-07-13 14:33:00
#
#     nvasc:context_79de34b1-eec9-48e2-aaac-482e1990b65c {
#         nvasc:synth_patient_3 a sio:Person ;
#             sio:has-role nvasc:role_3 .
#         nvasc:role_3 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_0fee2192-31b7-41af-9702-1918c35dcdbc .
#
#         nvasc:diag_0fee2192-31b7-41af-9702-1918c35dcdbc a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_c5a99f6a-0b73-4d7f-886e-847bb629d645 .
#
#         nvasc:diag_output_c5a99f6a-0b73-4d7f-886e-847bb629d645 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_79de34b1-eec9-48e2-aaac-482e1990b65c sio:SIO_000680 "2022-07-13T14:33:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-07-14T19:33:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_3 . # part-of
#
#         nvasc:timeline_3 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_3 ; # is-about
#                                 sio:SIO_000028 nvasc:context_79de34b1-eec9-48e2-aaac-482e1990b65c . # this is a materialization of the has-part property
#     }
#
# 53.0
# 2022-07-13 14:33:00
#
#     nvasc:context_978a07cf-d0ac-4a92-bc42-15b1bb2c6f20 {
#         nvasc:synth_patient_3 a sio:Person ;
#             sio:has-role nvasc:role_3 .
#         nvasc:role_3 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_aaed4263-1202-4cf1-95ad-88d49e900dc5 .
#
#         nvasc:diag_aaed4263-1202-4cf1-95ad-88d49e900dc5 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_e5dc8106-3753-4676-8259-bf0afd58625f .
#
#         nvasc:diag_output_e5dc8106-3753-4676-8259-bf0afd58625f a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_978a07cf-d0ac-4a92-bc42-15b1bb2c6f20 sio:SIO_000680 "2022-07-13T14:33:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-07-15T19:33:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_3 . # part-of
#
#         nvasc:timeline_3 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_3 ; # is-about
#                                 sio:SIO_000028 nvasc:context_978a07cf-d0ac-4a92-bc42-15b1bb2c6f20 . # this is a materialization of the has-part property
#     }
#
# 26.0
# 2020-09-15 13:03:00
#
#     nvasc:context_a671c4ef-1148-42c5-ba80-d0ed75d68725 {
#         nvasc:synth_patient_4 a sio:Person ;
#             sio:has-role nvasc:role_4 .
#         nvasc:role_4 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_49012ffb-7416-4b35-9099-999f8adc813c .
#
#         nvasc:diag_49012ffb-7416-4b35-9099-999f8adc813c a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_74ed5acf-e450-4cdb-bdf7-a019ed2b751e .
#
#         nvasc:diag_output_74ed5acf-e450-4cdb-bdf7-a019ed2b751e a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_a671c4ef-1148-42c5-ba80-d0ed75d68725 sio:SIO_000680 "2020-09-15T13:03:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-09-16T15:03:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_4 . # part-of
#
#         nvasc:timeline_4 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_4 ; # is-about
#                                 sio:SIO_000028 nvasc:context_a671c4ef-1148-42c5-ba80-d0ed75d68725 . # this is a materialization of the has-part property
#     }
#
# 79.0
# 2020-09-15 13:03:00
#
#     nvasc:context_01e72721-0ae4-40e4-89b9-4f5621d41780 {
#         nvasc:synth_patient_4 a sio:Person ;
#             sio:has-role nvasc:role_4 .
#         nvasc:role_4 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_15e9eda3-d6f8-4152-b705-175585cf950d .
#
#         nvasc:diag_15e9eda3-d6f8-4152-b705-175585cf950d a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_18bb3ead-af8d-4e0b-bd1f-fd87c7753856 .
#
#         nvasc:diag_output_18bb3ead-af8d-4e0b-bd1f-fd87c7753856 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_01e72721-0ae4-40e4-89b9-4f5621d41780 sio:SIO_000680 "2020-09-15T13:03:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-09-18T20:03:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_4 . # part-of
#
#         nvasc:timeline_4 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_4 ; # is-about
#                                 sio:SIO_000028 nvasc:context_01e72721-0ae4-40e4-89b9-4f5621d41780 . # this is a materialization of the has-part property
#     }
#
# 52.0
# 2020-09-15 13:03:00
#
#     nvasc:context_b407a5de-97b6-409a-8589-83d16afc84c1 {
#         nvasc:synth_patient_4 a sio:Person ;
#             sio:has-role nvasc:role_4 .
#         nvasc:role_4 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_4edb657a-f51d-44c1-b63f-42b1cf655950 .
#
#         nvasc:diag_4edb657a-f51d-44c1-b63f-42b1cf655950 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_79ccac01-d84e-4f8f-92dd-f91e286503dd .
#
#         nvasc:diag_output_79ccac01-d84e-4f8f-92dd-f91e286503dd a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_b407a5de-97b6-409a-8589-83d16afc84c1 sio:SIO_000680 "2020-09-15T13:03:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-09-17T17:03:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_4 . # part-of
#
#         nvasc:timeline_4 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_4 ; # is-about
#                                 sio:SIO_000028 nvasc:context_b407a5de-97b6-409a-8589-83d16afc84c1 . # this is a materialization of the has-part property
#     }
#
# 23.0
# 2020-12-03 19:36:00
#
#     nvasc:context_cc0599c1-b482-4ac2-b16d-826609041a7b {
#         nvasc:synth_patient_5 a sio:Person ;
#             sio:has-role nvasc:role_5 .
#         nvasc:role_5 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_567baff0-1de0-4241-ad11-fb01b623d404 .
#
#         nvasc:diag_567baff0-1de0-4241-ad11-fb01b623d404 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_a46b4325-ec01-49dd-8876-f223f3b45b08 .
#
#         nvasc:diag_output_a46b4325-ec01-49dd-8876-f223f3b45b08 a sio:InformationContentEntity,
#             ncit:N02BE01.
#     }
#
#     {
#         nvasc:context_cc0599c1-b482-4ac2-b16d-826609041a7b sio:SIO_000680 "2020-12-03T19:36:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-12-04T18:36:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_5 . # part-of
#
#         nvasc:timeline_5 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_5 ; # is-about
#                                 sio:SIO_000028 nvasc:context_cc0599c1-b482-4ac2-b16d-826609041a7b . # this is a materialization of the has-part property
#     }
#
# 26.0
# 2022-07-23 04:35:00
#
#     nvasc:context_053322ca-c0e4-41d0-bb26-26354bf6b8c7 {
#         nvasc:synth_patient_6 a sio:Person ;
#             sio:has-role nvasc:role_6 .
#         nvasc:role_6 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_f9e51de2-058d-41db-8c44-82ddc62208bc .
#
#         nvasc:diag_f9e51de2-058d-41db-8c44-82ddc62208bc a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_f483a14e-8541-4695-a8fc-8b138800dbc8 .
#
#         nvasc:diag_output_f483a14e-8541-4695-a8fc-8b138800dbc8 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_053322ca-c0e4-41d0-bb26-26354bf6b8c7 sio:SIO_000680 "2022-07-23T04:35:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-07-24T06:35:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_6 . # part-of
#
#         nvasc:timeline_6 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_6 ; # is-about
#                                 sio:SIO_000028 nvasc:context_053322ca-c0e4-41d0-bb26-26354bf6b8c7 . # this is a materialization of the has-part property
#     }
#
# 46.0
# 2022-07-23 04:35:00
#
#     nvasc:context_6f664074-70b9-4a95-814e-a6947ed27b96 {
#         nvasc:synth_patient_6 a sio:Person ;
#             sio:has-role nvasc:role_6 .
#         nvasc:role_6 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_e9a3d7b3-5db9-4196-a780-c25865a0aad5 .
#
#         nvasc:diag_e9a3d7b3-5db9-4196-a780-c25865a0aad5 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_e3a39867-6fe1-407d-af57-2b0032e4a0da .
#
#         nvasc:diag_output_e3a39867-6fe1-407d-af57-2b0032e4a0da a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_6f664074-70b9-4a95-814e-a6947ed27b96 sio:SIO_000680 "2022-07-23T04:35:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-07-25T02:35:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_6 . # part-of
#
#         nvasc:timeline_6 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_6 ; # is-about
#                                 sio:SIO_000028 nvasc:context_6f664074-70b9-4a95-814e-a6947ed27b96 . # this is a materialization of the has-part property
#     }
#
# 35.0
# 2021-11-19 14:41:00
#
#     nvasc:context_04acf389-638f-4701-ad3f-214437152c58 {
#         nvasc:synth_patient_7 a sio:Person ;
#             sio:has-role nvasc:role_7 .
#         nvasc:role_7 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_4696bebf-c737-430c-8c6d-1f9ee9f15bec .
#
#         nvasc:diag_4696bebf-c737-430c-8c6d-1f9ee9f15bec a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_50c1b14f-cf4d-4cc2-b5cc-9796fd0fa407 .
#
#         nvasc:diag_output_50c1b14f-cf4d-4cc2-b5cc-9796fd0fa407 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_04acf389-638f-4701-ad3f-214437152c58 sio:SIO_000680 "2021-11-19T14:41:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-11-21T01:41:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_7 . # part-of
#
#         nvasc:timeline_7 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_7 ; # is-about
#                                 sio:SIO_000028 nvasc:context_04acf389-638f-4701-ad3f-214437152c58 . # this is a materialization of the has-part property
#     }
#
# 53.0
# 2021-11-19 14:41:00
#
#     nvasc:context_4e21f343-9794-465d-8a48-0cd974e84312 {
#         nvasc:synth_patient_7 a sio:Person ;
#             sio:has-role nvasc:role_7 .
#         nvasc:role_7 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_16fcedd4-b713-4ec1-92a6-7f41f9c11d27 .
#
#         nvasc:diag_16fcedd4-b713-4ec1-92a6-7f41f9c11d27 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_b909cd32-6eeb-4db9-9f41-eba8c9b71be2 .
#
#         nvasc:diag_output_b909cd32-6eeb-4db9-9f41-eba8c9b71be2 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_4e21f343-9794-465d-8a48-0cd974e84312 sio:SIO_000680 "2021-11-19T14:41:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-11-21T19:41:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_7 . # part-of
#
#         nvasc:timeline_7 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_7 ; # is-about
#                                 sio:SIO_000028 nvasc:context_4e21f343-9794-465d-8a48-0cd974e84312 . # this is a materialization of the has-part property
#     }
#
# 29.0
# 2020-08-05 09:42:00
#
#     nvasc:context_89bd6dee-5b16-46d5-81d6-e30fe3a1e628 {
#         nvasc:synth_patient_8 a sio:Person ;
#             sio:has-role nvasc:role_8 .
#         nvasc:role_8 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_266bbbea-c77b-4837-b37b-c0b9a64d2f39 .
#
#         nvasc:diag_266bbbea-c77b-4837-b37b-c0b9a64d2f39 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_832ff3cd-6c23-4d48-9805-9501f83215e3 .
#
#         nvasc:diag_output_832ff3cd-6c23-4d48-9805-9501f83215e3 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_89bd6dee-5b16-46d5-81d6-e30fe3a1e628 sio:SIO_000680 "2020-08-05T09:42:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-08-06T14:42:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_8 . # part-of
#
#         nvasc:timeline_8 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_8 ; # is-about
#                                 sio:SIO_000028 nvasc:context_89bd6dee-5b16-46d5-81d6-e30fe3a1e628 . # this is a materialization of the has-part property
#     }
#
# 32.0
# 2021-11-02 06:54:00
#
#     nvasc:context_b7f35a37-9262-4f77-b2b9-9fd31ab9bb6c {
#         nvasc:synth_patient_9 a sio:Person ;
#             sio:has-role nvasc:role_9 .
#         nvasc:role_9 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_26a353f5-47b8-4d0c-8be6-a6961691bfdd .
#
#         nvasc:diag_26a353f5-47b8-4d0c-8be6-a6961691bfdd a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_832ebeea-ce86-4c38-a85e-0df2abf450fa .
#
#         nvasc:diag_output_832ebeea-ce86-4c38-a85e-0df2abf450fa a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_b7f35a37-9262-4f77-b2b9-9fd31ab9bb6c sio:SIO_000680 "2021-11-02T06:54:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-11-03T14:54:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_9 . # part-of
#
#         nvasc:timeline_9 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_9 ; # is-about
#                                 sio:SIO_000028 nvasc:context_b7f35a37-9262-4f77-b2b9-9fd31ab9bb6c . # this is a materialization of the has-part property
#     }
#
# 25.0
# 2020-02-07 17:36:00
#
#     nvasc:context_fd210b24-7419-4442-8aab-8499e363dad7 {
#         nvasc:synth_patient_10 a sio:Person ;
#             sio:has-role nvasc:role_10 .
#         nvasc:role_10 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_4aad63f4-5ea8-4f49-9045-bfa053f13a1a .
#
#         nvasc:diag_4aad63f4-5ea8-4f49-9045-bfa053f13a1a a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_245f9819-a87c-44ca-b699-fd62626f2459 .
#
#         nvasc:diag_output_245f9819-a87c-44ca-b699-fd62626f2459 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_fd210b24-7419-4442-8aab-8499e363dad7 sio:SIO_000680 "2020-02-07T17:36:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-02-08T18:36:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_10 . # part-of
#
#         nvasc:timeline_10 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_10 ; # is-about
#                                 sio:SIO_000028 nvasc:context_fd210b24-7419-4442-8aab-8499e363dad7 . # this is a materialization of the has-part property
#     }
#
# 71.0
# 2020-02-07 17:36:00
#
#     nvasc:context_828eeed3-2fc4-4c78-a7fe-01176a96842f {
#         nvasc:synth_patient_10 a sio:Person ;
#             sio:has-role nvasc:role_10 .
#         nvasc:role_10 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_9ec8680a-9e8a-4271-8f0e-09aa2f2d1d67 .
#
#         nvasc:diag_9ec8680a-9e8a-4271-8f0e-09aa2f2d1d67 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_0e9e4055-2d34-4e32-a541-02613d70d4a7 .
#
#         nvasc:diag_output_0e9e4055-2d34-4e32-a541-02613d70d4a7 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_828eeed3-2fc4-4c78-a7fe-01176a96842f sio:SIO_000680 "2020-02-07T17:36:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-02-10T16:36:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_10 . # part-of
#
#         nvasc:timeline_10 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_10 ; # is-about
#                                 sio:SIO_000028 nvasc:context_828eeed3-2fc4-4c78-a7fe-01176a96842f . # this is a materialization of the has-part property
#     }
#
# 88.0
# 2020-02-07 17:36:00
#
#     nvasc:context_2990155c-6e9d-46b6-85ab-a562cc7bf4b6 {
#         nvasc:synth_patient_10 a sio:Person ;
#             sio:has-role nvasc:role_10 .
#         nvasc:role_10 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_427adfaa-bdb5-4c76-90f5-5a1ce42d661c .
#
#         nvasc:diag_427adfaa-bdb5-4c76-90f5-5a1ce42d661c a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_aae0d8cf-83f2-492a-9069-e954ee4566e2 .
#
#         nvasc:diag_output_aae0d8cf-83f2-492a-9069-e954ee4566e2 a sio:InformationContentEntity,
#             ncit:Z98.6.
#     }
#
#     {
#         nvasc:context_2990155c-6e9d-46b6-85ab-a562cc7bf4b6 sio:SIO_000680 "2020-02-07T17:36:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-02-11T09:36:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_10 . # part-of
#
#         nvasc:timeline_10 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_10 ; # is-about
#                                 sio:SIO_000028 nvasc:context_2990155c-6e9d-46b6-85ab-a562cc7bf4b6 . # this is a materialization of the has-part property
#     }
#
# 47.0
# 2020-02-07 17:36:00
#
#     nvasc:context_fa4b2da8-9b23-43f7-9540-8d0e5457551c {
#         nvasc:synth_patient_10 a sio:Person ;
#             sio:has-role nvasc:role_10 .
#         nvasc:role_10 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_104710d4-d2c1-40c6-a5e2-b606d6d11742 .
#
#         nvasc:diag_104710d4-d2c1-40c6-a5e2-b606d6d11742 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_687a491e-f22b-443d-b776-2b8364be2170 .
#
#         nvasc:diag_output_687a491e-f22b-443d-b776-2b8364be2170 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_fa4b2da8-9b23-43f7-9540-8d0e5457551c sio:SIO_000680 "2020-02-07T17:36:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-02-09T16:36:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_10 . # part-of
#
#         nvasc:timeline_10 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_10 ; # is-about
#                                 sio:SIO_000028 nvasc:context_fa4b2da8-9b23-43f7-9540-8d0e5457551c . # this is a materialization of the has-part property
#     }
#
# 22.0
# 2021-05-29 17:27:00
#
#     nvasc:context_06d95bca-0d95-4825-8974-96363b25eba2 {
#         nvasc:synth_patient_11 a sio:Person ;
#             sio:has-role nvasc:role_11 .
#         nvasc:role_11 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_731a4753-ab98-433e-ba1e-74d62f5098a5 .
#
#         nvasc:diag_731a4753-ab98-433e-ba1e-74d62f5098a5 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_ff2f4a41-3914-4ea3-898e-e7cf15dd0fb0 .
#
#         nvasc:diag_output_ff2f4a41-3914-4ea3-898e-e7cf15dd0fb0 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_06d95bca-0d95-4825-8974-96363b25eba2 sio:SIO_000680 "2021-05-29T17:27:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-05-30T15:27:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_11 . # part-of
#
#         nvasc:timeline_11 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_11 ; # is-about
#                                 sio:SIO_000028 nvasc:context_06d95bca-0d95-4825-8974-96363b25eba2 . # this is a materialization of the has-part property
#     }
#
# 42.0
# 2021-05-29 17:27:00
#
#     nvasc:context_69abba01-c604-4517-afb3-aaab8eba4bf8 {
#         nvasc:synth_patient_11 a sio:Person ;
#             sio:has-role nvasc:role_11 .
#         nvasc:role_11 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_f7cefb97-eb4a-4531-b121-32c24e4a7931 .
#
#         nvasc:diag_f7cefb97-eb4a-4531-b121-32c24e4a7931 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_613af395-35e1-4fc9-856c-e8aaeb44a7d9 .
#
#         nvasc:diag_output_613af395-35e1-4fc9-856c-e8aaeb44a7d9 a sio:InformationContentEntity,
#             ncit:N02BE01.
#     }
#
#     {
#         nvasc:context_69abba01-c604-4517-afb3-aaab8eba4bf8 sio:SIO_000680 "2021-05-29T17:27:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-05-31T11:27:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_11 . # part-of
#
#         nvasc:timeline_11 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_11 ; # is-about
#                                 sio:SIO_000028 nvasc:context_69abba01-c604-4517-afb3-aaab8eba4bf8 . # this is a materialization of the has-part property
#     }
#
# 62.0
# 2021-05-29 17:27:00
#
#     nvasc:context_836508f0-937a-4bec-8f00-85db9669dca5 {
#         nvasc:synth_patient_11 a sio:Person ;
#             sio:has-role nvasc:role_11 .
#         nvasc:role_11 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_90f1065a-1db9-4f47-a8e8-dfdc5685a1ff .
#
#         nvasc:diag_90f1065a-1db9-4f47-a8e8-dfdc5685a1ff a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_6b12b151-52f9-400b-a0f6-2ed0aa38efda .
#
#         nvasc:diag_output_6b12b151-52f9-400b-a0f6-2ed0aa38efda a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_836508f0-937a-4bec-8f00-85db9669dca5 sio:SIO_000680 "2021-05-29T17:27:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-06-01T07:27:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_11 . # part-of
#
#         nvasc:timeline_11 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_11 ; # is-about
#                                 sio:SIO_000028 nvasc:context_836508f0-937a-4bec-8f00-85db9669dca5 . # this is a materialization of the has-part property
#     }
#
# 67.0
# 2021-09-02 12:37:00
#
#     nvasc:context_8edb8314-ef22-42fa-9446-235be3a9fb7f {
#         nvasc:synth_patient_12 a sio:Person ;
#             sio:has-role nvasc:role_12 .
#         nvasc:role_12 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_fc84806e-976f-4304-bd19-4e19a26571cd .
#
#         nvasc:diag_fc84806e-976f-4304-bd19-4e19a26571cd a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_1213210f-6f3f-42a7-85ae-a196df3c9e66 .
#
#         nvasc:diag_output_1213210f-6f3f-42a7-85ae-a196df3c9e66 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_8edb8314-ef22-42fa-9446-235be3a9fb7f sio:SIO_000680 "2021-09-02T12:37:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-09-05T07:37:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_12 . # part-of
#
#         nvasc:timeline_12 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_12 ; # is-about
#                                 sio:SIO_000028 nvasc:context_8edb8314-ef22-42fa-9446-235be3a9fb7f . # this is a materialization of the has-part property
#     }
#
# 38.0
# 2021-09-02 12:37:00
#
#     nvasc:context_d0a4c72f-fda5-4576-b3cb-fd8571d8fccf {
#         nvasc:synth_patient_12 a sio:Person ;
#             sio:has-role nvasc:role_12 .
#         nvasc:role_12 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_427fc0e8-efb6-44f6-b68f-65f247c070bb .
#
#         nvasc:diag_427fc0e8-efb6-44f6-b68f-65f247c070bb a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_3f001bb1-1654-4057-81cf-8555adaec6e7 .
#
#         nvasc:diag_output_3f001bb1-1654-4057-81cf-8555adaec6e7 a sio:InformationContentEntity,
#             ncit:N02BE01.
#     }
#
#     {
#         nvasc:context_d0a4c72f-fda5-4576-b3cb-fd8571d8fccf sio:SIO_000680 "2021-09-02T12:37:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-09-04T02:37:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_12 . # part-of
#
#         nvasc:timeline_12 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_12 ; # is-about
#                                 sio:SIO_000028 nvasc:context_d0a4c72f-fda5-4576-b3cb-fd8571d8fccf . # this is a materialization of the has-part property
#     }
#
# 91.0
# 2021-09-02 12:37:00
#
#     nvasc:context_20b91876-190f-40f2-ad03-d2fbdb5fac95 {
#         nvasc:synth_patient_12 a sio:Person ;
#             sio:has-role nvasc:role_12 .
#         nvasc:role_12 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_ff6b769d-8122-4a1d-9a4f-785cbf91178e .
#
#         nvasc:diag_ff6b769d-8122-4a1d-9a4f-785cbf91178e a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_a681cf5d-2065-4aaf-8df3-51361e92af0d .
#
#         nvasc:diag_output_a681cf5d-2065-4aaf-8df3-51361e92af0d a sio:InformationContentEntity,
#             ncit:N02AA01.
#     }
#
#     {
#         nvasc:context_20b91876-190f-40f2-ad03-d2fbdb5fac95 sio:SIO_000680 "2021-09-02T12:37:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-09-06T07:37:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_12 . # part-of
#
#         nvasc:timeline_12 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_12 ; # is-about
#                                 sio:SIO_000028 nvasc:context_20b91876-190f-40f2-ad03-d2fbdb5fac95 . # this is a materialization of the has-part property
#     }
#
# 26.0
# 2021-09-02 12:37:00
#
#     nvasc:context_21aaeb52-abd4-4f3a-9fa0-2f4e129040e7 {
#         nvasc:synth_patient_12 a sio:Person ;
#             sio:has-role nvasc:role_12 .
#         nvasc:role_12 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_6690c064-3d69-4505-a899-121de066073b .
#
#         nvasc:diag_6690c064-3d69-4505-a899-121de066073b a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_f57f9d1d-27dd-4821-ba9a-edfcd5df521f .
#
#         nvasc:diag_output_f57f9d1d-27dd-4821-ba9a-edfcd5df521f a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_21aaeb52-abd4-4f3a-9fa0-2f4e129040e7 sio:SIO_000680 "2021-09-02T12:37:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-09-03T14:37:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_12 . # part-of
#
#         nvasc:timeline_12 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_12 ; # is-about
#                                 sio:SIO_000028 nvasc:context_21aaeb52-abd4-4f3a-9fa0-2f4e129040e7 . # this is a materialization of the has-part property
#     }
#
# 47.0
# 2022-11-20 16:22:00
#
#     nvasc:context_bfb0dc57-59fa-46ab-8313-a91c4e8537e9 {
#         nvasc:synth_patient_13 a sio:Person ;
#             sio:has-role nvasc:role_13 .
#         nvasc:role_13 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_9f82aeff-f801-4325-a2ba-c97990e0e27b .
#
#         nvasc:diag_9f82aeff-f801-4325-a2ba-c97990e0e27b a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_7904fad4-fa01-4b90-99b9-6b385961298c .
#
#         nvasc:diag_output_7904fad4-fa01-4b90-99b9-6b385961298c a sio:InformationContentEntity,
#             ncit:C01CA03.
#     }
#
#     {
#         nvasc:context_bfb0dc57-59fa-46ab-8313-a91c4e8537e9 sio:SIO_000680 "2022-11-20T16:22:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-11-22T15:22:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_13 . # part-of
#
#         nvasc:timeline_13 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_13 ; # is-about
#                                 sio:SIO_000028 nvasc:context_bfb0dc57-59fa-46ab-8313-a91c4e8537e9 . # this is a materialization of the has-part property
#     }
#
# 28.0
# 2022-11-20 16:22:00
#
#     nvasc:context_0f2df5ce-b5db-44cd-a8e1-9f3956ec9870 {
#         nvasc:synth_patient_13 a sio:Person ;
#             sio:has-role nvasc:role_13 .
#         nvasc:role_13 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_2db258f9-00e0-4a21-829e-2d405ed72ced .
#
#         nvasc:diag_2db258f9-00e0-4a21-829e-2d405ed72ced a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_c12f8d7d-ca0a-4e83-b323-1e2056d751e0 .
#
#         nvasc:diag_output_c12f8d7d-ca0a-4e83-b323-1e2056d751e0 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_0f2df5ce-b5db-44cd-a8e1-9f3956ec9870 sio:SIO_000680 "2022-11-20T16:22:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-11-21T20:22:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_13 . # part-of
#
#         nvasc:timeline_13 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_13 ; # is-about
#                                 sio:SIO_000028 nvasc:context_0f2df5ce-b5db-44cd-a8e1-9f3956ec9870 . # this is a materialization of the has-part property
#     }
#
# 66.0
# 2022-11-20 16:22:00
#
#     nvasc:context_0db62e11-fc5b-4dc5-93e2-e34ea04f21a9 {
#         nvasc:synth_patient_13 a sio:Person ;
#             sio:has-role nvasc:role_13 .
#         nvasc:role_13 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_a4ec5851-8d66-49e1-b247-cee61c704b13 .
#
#         nvasc:diag_a4ec5851-8d66-49e1-b247-cee61c704b13 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_0ebaac02-dbf5-4d01-b0fe-5dbe3198ab74 .
#
#         nvasc:diag_output_0ebaac02-dbf5-4d01-b0fe-5dbe3198ab74 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_0db62e11-fc5b-4dc5-93e2-e34ea04f21a9 sio:SIO_000680 "2022-11-20T16:22:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-11-23T10:22:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_13 . # part-of
#
#         nvasc:timeline_13 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_13 ; # is-about
#                                 sio:SIO_000028 nvasc:context_0db62e11-fc5b-4dc5-93e2-e34ea04f21a9 . # this is a materialization of the has-part property
#     }
#
# 24.0
# 2020-06-17 08:35:00
#
#     nvasc:context_a73944eb-6477-4ecf-baf0-6b12a5493ea2 {
#         nvasc:synth_patient_14 a sio:Person ;
#             sio:has-role nvasc:role_14 .
#         nvasc:role_14 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_f99ec18b-e553-4353-ab62-a4bf0bef77c8 .
#
#         nvasc:diag_f99ec18b-e553-4353-ab62-a4bf0bef77c8 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_b75a2f67-9873-4925-a6f9-e05d61764e82 .
#
#         nvasc:diag_output_b75a2f67-9873-4925-a6f9-e05d61764e82 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_a73944eb-6477-4ecf-baf0-6b12a5493ea2 sio:SIO_000680 "2020-06-17T08:35:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-06-18T08:35:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_14 . # part-of
#
#         nvasc:timeline_14 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_14 ; # is-about
#                                 sio:SIO_000028 nvasc:context_a73944eb-6477-4ecf-baf0-6b12a5493ea2 . # this is a materialization of the has-part property
#     }
#
# 21.0
# 2020-01-31 14:11:00
#
#     nvasc:context_93017661-b32b-4f66-9bea-32000ccc2adf {
#         nvasc:synth_patient_15 a sio:Person ;
#             sio:has-role nvasc:role_15 .
#         nvasc:role_15 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_76dbf38f-4176-4fed-a790-4f81028000a3 .
#
#         nvasc:diag_76dbf38f-4176-4fed-a790-4f81028000a3 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_1d612761-1516-49b9-b022-0aec7dae1f74 .
#
#         nvasc:diag_output_1d612761-1516-49b9-b022-0aec7dae1f74 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_93017661-b32b-4f66-9bea-32000ccc2adf sio:SIO_000680 "2020-01-31T14:11:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-02-01T11:11:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_15 . # part-of
#
# ...
#     }
#
#     {
#         nvasc:context_34007e56-b9ab-45ad-abde-c1f9e8948c6e sio:SIO_000680 "2021-02-04T02:24:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-02-08T10:24:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_96 . # part-of
#
#         nvasc:timeline_96 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_96 ; # is-about
#                                 sio:SIO_000028 nvasc:context_34007e56-b9ab-45ad-abde-c1f9e8948c6e . # this is a materialization of the has-part property
#     }
#
# 74.0
# 2021-02-04 02:24:00
#
#     nvasc:context_329bbb5c-b09c-46d0-8df1-9cfd614b53aa {
#         nvasc:synth_patient_96 a sio:Person ;
#             sio:has-role nvasc:role_96 .
#         nvasc:role_96 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_cfca9ed6-376e-412c-9293-9e60dd58ac91 .
#
#         nvasc:diag_cfca9ed6-376e-412c-9293-9e60dd58ac91 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_0c82baa4-4a97-46ee-a5fc-4339a202be9b .
#
#         nvasc:diag_output_0c82baa4-4a97-46ee-a5fc-4339a202be9b a sio:InformationContentEntity,
#             ncit:C01CA03.
#     }
#
#     {
#         nvasc:context_329bbb5c-b09c-46d0-8df1-9cfd614b53aa sio:SIO_000680 "2021-02-04T02:24:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-02-07T04:24:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_96 . # part-of
#
#         nvasc:timeline_96 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_96 ; # is-about
#                                 sio:SIO_000028 nvasc:context_329bbb5c-b09c-46d0-8df1-9cfd614b53aa . # this is a materialization of the has-part property
#     }
#
# 54.0
# 2021-02-04 02:24:00
#
#     nvasc:context_e8a64190-17d4-4988-9c91-5ea10f654371 {
#         nvasc:synth_patient_96 a sio:Person ;
#             sio:has-role nvasc:role_96 .
#         nvasc:role_96 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_44c6fb14-be1a-4384-9781-d8e4e99c9b0e .
#
#         nvasc:diag_44c6fb14-be1a-4384-9781-d8e4e99c9b0e a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_0bf0fc9c-65e1-4919-93cd-6c76bb651dd2 .
#
#         nvasc:diag_output_0bf0fc9c-65e1-4919-93cd-6c76bb651dd2 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_e8a64190-17d4-4988-9c91-5ea10f654371 sio:SIO_000680 "2021-02-04T02:24:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-02-06T08:24:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_96 . # part-of
#
#         nvasc:timeline_96 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_96 ; # is-about
#                                 sio:SIO_000028 nvasc:context_e8a64190-17d4-4988-9c91-5ea10f654371 . # this is a materialization of the has-part property
#     }
#
# 26.0
# 2021-02-04 02:24:00
#
#     nvasc:context_f8167de4-0fc7-4fb8-9f54-59bda6d20fe4 {
#         nvasc:synth_patient_96 a sio:Person ;
#             sio:has-role nvasc:role_96 .
#         nvasc:role_96 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_0c17c474-e92d-4621-aaa7-11f563648e8e .
#
#         nvasc:diag_0c17c474-e92d-4621-aaa7-11f563648e8e a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_b131fee3-4582-4c3a-b52a-ca9740b36f58 .
#
#         nvasc:diag_output_b131fee3-4582-4c3a-b52a-ca9740b36f58 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_f8167de4-0fc7-4fb8-9f54-59bda6d20fe4 sio:SIO_000680 "2021-02-04T02:24:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-02-05T04:24:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_96 . # part-of
#
#         nvasc:timeline_96 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_96 ; # is-about
#                                 sio:SIO_000028 nvasc:context_f8167de4-0fc7-4fb8-9f54-59bda6d20fe4 . # this is a materialization of the has-part property
#     }
#
# 49.0
# 2021-01-11 12:20:00
#
#     nvasc:context_a19a27c6-7732-49b1-8c77-3c5818d36a09 {
#         nvasc:synth_patient_97 a sio:Person ;
#             sio:has-role nvasc:role_97 .
#         nvasc:role_97 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_df92a150-0a43-4e51-92c9-5689dac96a4f .
#
#         nvasc:diag_df92a150-0a43-4e51-92c9-5689dac96a4f a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_ca5aab88-22e6-4823-8a32-1fef18c282d0 .
#
#         nvasc:diag_output_ca5aab88-22e6-4823-8a32-1fef18c282d0 a sio:InformationContentEntity,
#             ncit:C08CA06.
#     }
#
#     {
#         nvasc:context_a19a27c6-7732-49b1-8c77-3c5818d36a09 sio:SIO_000680 "2021-01-11T12:20:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-01-13T13:20:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_97 . # part-of
#
#         nvasc:timeline_97 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_97 ; # is-about
#                                 sio:SIO_000028 nvasc:context_a19a27c6-7732-49b1-8c77-3c5818d36a09 . # this is a materialization of the has-part property
#     }
#
# 27.0
# 2021-01-11 12:20:00
#
#     nvasc:context_8ff71d2f-5e34-42fb-86d0-a443a00c1e10 {
#         nvasc:synth_patient_97 a sio:Person ;
#             sio:has-role nvasc:role_97 .
#         nvasc:role_97 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_b3bfdf57-8fce-4d7d-85e5-3a886405bdd0 .
#
#         nvasc:diag_b3bfdf57-8fce-4d7d-85e5-3a886405bdd0 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_0abe24ae-5ba2-4560-92f9-7a020a98d1c7 .
#
#         nvasc:diag_output_0abe24ae-5ba2-4560-92f9-7a020a98d1c7 a sio:InformationContentEntity,
#             ncit:N02BE01.
#     }
#
#     {
#         nvasc:context_8ff71d2f-5e34-42fb-86d0-a443a00c1e10 sio:SIO_000680 "2021-01-11T12:20:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-01-12T15:20:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_97 . # part-of
#
#         nvasc:timeline_97 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_97 ; # is-about
#                                 sio:SIO_000028 nvasc:context_8ff71d2f-5e34-42fb-86d0-a443a00c1e10 . # this is a materialization of the has-part property
#     }
#
# 102.0
# 2021-01-11 12:20:00
#
#     nvasc:context_ea826b55-6230-4603-baef-529bd31b1e20 {
#         nvasc:synth_patient_97 a sio:Person ;
#             sio:has-role nvasc:role_97 .
#         nvasc:role_97 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_771e1388-7d76-4e8e-854e-edb72468d1ca .
#
#         nvasc:diag_771e1388-7d76-4e8e-854e-edb72468d1ca a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_c89bd469-e73c-43d0-8448-6b83d55b817f .
#
#         nvasc:diag_output_c89bd469-e73c-43d0-8448-6b83d55b817f a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_ea826b55-6230-4603-baef-529bd31b1e20 sio:SIO_000680 "2021-01-11T12:20:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-01-15T18:20:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_97 . # part-of
#
#         nvasc:timeline_97 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_97 ; # is-about
#                                 sio:SIO_000028 nvasc:context_ea826b55-6230-4603-baef-529bd31b1e20 . # this is a materialization of the has-part property
#     }
#
# 75.0
# 2021-01-11 12:20:00
#
#     nvasc:context_95b5e7a1-4f15-41aa-ad1a-98b5af13756c {
#         nvasc:synth_patient_97 a sio:Person ;
#             sio:has-role nvasc:role_97 .
#         nvasc:role_97 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_eaddfc16-588c-4c27-b019-7ca6392a1b40 .
#
#         nvasc:diag_eaddfc16-588c-4c27-b019-7ca6392a1b40 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_598c55c8-6335-4484-9f17-a158477a8f73 .
#
#         nvasc:diag_output_598c55c8-6335-4484-9f17-a158477a8f73 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_95b5e7a1-4f15-41aa-ad1a-98b5af13756c sio:SIO_000680 "2021-01-11T12:20:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2021-01-14T15:20:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_97 . # part-of
#
#         nvasc:timeline_97 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_97 ; # is-about
#                                 sio:SIO_000028 nvasc:context_95b5e7a1-4f15-41aa-ad1a-98b5af13756c . # this is a materialization of the has-part property
#     }
#
# 23.0
# 2022-10-14 13:05:00
#
#     nvasc:context_225d9bfc-6750-4aca-841d-bf4d0b3accc9 {
#         nvasc:synth_patient_98 a sio:Person ;
#             sio:has-role nvasc:role_98 .
#         nvasc:role_98 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_5723339e-03f3-4071-9451-45b52002d3d8 .
#
#         nvasc:diag_5723339e-03f3-4071-9451-45b52002d3d8 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_c8911681-16d6-4d1f-9e2c-7525199932f6 .
#
#         nvasc:diag_output_c8911681-16d6-4d1f-9e2c-7525199932f6 a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_225d9bfc-6750-4aca-841d-bf4d0b3accc9 sio:SIO_000680 "2022-10-14T13:05:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-10-15T12:05:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_98 . # part-of
#
#         nvasc:timeline_98 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_98 ; # is-about
#                                 sio:SIO_000028 nvasc:context_225d9bfc-6750-4aca-841d-bf4d0b3accc9 . # this is a materialization of the has-part property
#     }
#
# 50.0
# 2022-10-14 13:05:00
#
#     nvasc:context_d820a637-5c8f-4e48-b8b1-c5caf2c55db8 {
#         nvasc:synth_patient_98 a sio:Person ;
#             sio:has-role nvasc:role_98 .
#         nvasc:role_98 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_6be32033-b119-4ccc-a616-17b54efba509 .
#
#         nvasc:diag_6be32033-b119-4ccc-a616-17b54efba509 a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_11f2c413-2f96-438d-a00d-0c0f8ea5d707 .
#
#         nvasc:diag_output_11f2c413-2f96-438d-a00d-0c0f8ea5d707 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_d820a637-5c8f-4e48-b8b1-c5caf2c55db8 sio:SIO_000680 "2022-10-14T13:05:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2022-10-16T15:05:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_98 . # part-of
#
#         nvasc:timeline_98 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_98 ; # is-about
#                                 sio:SIO_000028 nvasc:context_d820a637-5c8f-4e48-b8b1-c5caf2c55db8 . # this is a materialization of the has-part property
#     }
#
# 21.0
# 2020-01-12 06:15:00
#
#     nvasc:context_8473a694-90f1-4a60-b80f-352f5a00772b {
#         nvasc:synth_patient_99 a sio:Person ;
#             sio:has-role nvasc:role_99 .
#         nvasc:role_99 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_661bc2ac-de30-431d-b939-0555cf542cfa .
#
#         nvasc:diag_661bc2ac-de30-431d-b939-0555cf542cfa a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_5f705ad2-6dd8-409c-8e08-d1d8eef4f32f .
#
#         nvasc:diag_output_5f705ad2-6dd8-409c-8e08-d1d8eef4f32f a sio:InformationContentEntity,
#             ncit:00P6X0Z.
#     }
#
#     {
#         nvasc:context_8473a694-90f1-4a60-b80f-352f5a00772b sio:SIO_000680 "2020-01-12T06:15:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-01-13T03:15:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_99 . # part-of
#
#         nvasc:timeline_99 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_99 ; # is-about
#                                 sio:SIO_000028 nvasc:context_8473a694-90f1-4a60-b80f-352f5a00772b . # this is a materialization of the has-part property
#     }
#
# 47.0
# 2020-01-12 06:15:00
#
#     nvasc:context_ba469f18-03c9-453b-a81f-99f22d3b985f {
#         nvasc:synth_patient_99 a sio:Person ;
#             sio:has-role nvasc:role_99 .
#         nvasc:role_99 a sio:Role, <http://purl.obolibrary.org/obo/OBI_0000093> ;
#             sio:is-realized-in nvasc:diag_4e2fae19-9846-4d44-9573-f1f961ccdf4f .
#
#         nvasc:diag_4e2fae19-9846-4d44-9573-f1f961ccdf4f a sio:Process, <http://purl.obolibrary.org/obo/NCIT_C18020> ;
#             sio:has-output nvasc:diag_output_10945a81-026a-4c6b-b0db-b8d1da66fc47 .
#
#         nvasc:diag_output_10945a81-026a-4c6b-b0db-b8d1da66fc47 a sio:InformationContentEntity,
#             ncit:0BH17EZ.
#     }
#
#     {
#         nvasc:context_ba469f18-03c9-453b-a81f-99f22d3b985f sio:SIO_000680 "2020-01-12T06:15:00"^^xsd:dateTime ;
#                               sio:SIO_000681 "2020-01-14T05:15:00"^^xsd:dateTime ;
#                               sio:SIO_000068 nvasc:timeline_99 . # part-of
#
#         nvasc:timeline_99 a sio:SIO_000417, <http://purl.obolibrary.org/obo/NCIT_C54576> ;
#                                 sio:SIO_000332 nvasc:synth_patient_99 ; # is-about
#                                 sio:SIO_000028 nvasc:context_ba469f18-03c9-453b-a81f-99f22d3b985f . # this is a materialization of the has-part property
#     }
#
# Generated 17110 RDF triples
# <Graph identifier=N6c5dbded71f14821a078f06c9703bd46 (<class 'rdflib.graph.ConjunctiveGraph'>)>

# %% [markdown]
# # Computing the duration of care events

# %%
## Understanding this code ... 
events = ['nimodipine',  'paracetamol', 'nad', 'corotrop', 'morphine', 'dve', 'atl', 'iot']
events_end = events + ['finish']

transitions = pd.read_csv('./care_transitions_probs.csv', index_col=0)
transitions

start_probs = [0.47381546, 0.09476309, 0.00997506, 0, 0.00997506, 0.24189526, 0.00249377, 0.16708229, 0]

# Generate a sequence of care events 
# The sequence is generated by starting with an initial event and then randomly selecting the next event based on the transition probabilities
def generate_care_path():
    event = np.random.choice(events_end, size=1, p=start_probs)[0]
    path = [event]

    while event != 'finish':
        event = np.random.choice(events_end, size=1, p=transitions[event].values)[0]
        # ensure that their is no duplicate event
        if event in path:
            event = 'finish'
        path += [event]
        
    # remove the finish event and return the path
    return path[:-1]
    

def generate_times_path(path):
    # Generate the time taken (in hour) for each event with a normal distribution with parameters mean=24 and std=5
    indv_times = map(round, norm.rvs(24, 5, len(path)))
    acc_times = list(accumulate(indv_times))
    # print(list(acc_times))

    sol = [-1] * len(events)
    # print(sol)
    for i, e in enumerate(path):
        sol[events.index(e)] = acc_times[i]
    
    # print(sol)
    return sol

# %%
generate_care_path()
# Out:
# ['dve', 'nad', 'paracetamol', 'nimodipine']

# %%
df_events = pd.DataFrame([generate_times_path(generate_care_path()) for _ in range(5)], columns=events)
df_events
# Out:
#    nimodipine  paracetamol  nad  corotrop  morphine  dve  atl  iot
# 0          24           -1   -1        -1        -1   -1   -1   -1
# 1          24           50   -1        -1        -1   -1   -1   -1
# 2          -1           -1   -1        -1        -1   18   -1   -1
# 3          -1           -1   -1        50        -1   22   -1   62
# 4          29           -1   -1        -1        -1   70   -1   46
