# %% [markdown]
# # Transformation of tabular dataset into SPHN RDF data

# %%
import pandas as pd
import numpy as np
import joblib
import re
import uuid
from rdflib import ConjunctiveGraph
from string import Template
from itertools import accumulate
from scipy.stats import norm, genextreme, exponweib
from datetime import datetime, date, timedelta

# %%
df = pd.read_csv('./syn_data.csv', index_col=0)
df
# Out:
#       hospital_stay_length        gcs     nb_acte  gender  entry  output  \
# 0                41.089445  17.086233   34.307297       0      0     0.0
# 1                21.702298  18.805639  133.523169       0      1     1.0
# 2                 4.627752  19.516216   85.648533       0      2     0.0
# 3                12.830087  19.940518   17.982208       1      1     2.0
# 4                75.675201  21.665547  132.859962       0      3     1.0
# ...                    ...        ...         ...     ...    ...     ...
# 9995             23.668646  18.302874   41.950003       1      5     2.0
# 9996             33.643450  20.634914   84.554423       0      1     1.0
# 9997             18.122234  15.604823    4.792264       1      5     2.0
# 9998             43.964242  18.368290    4.802513       1      2     1.0
# 9999             19.324875  19.904317  103.597895       0      5     1.0
#
#       entry_code  ica  ttt  ica_therapy  ...  ivh        age  nimodipine  \
# 0              0    0    0            0  ...    0  38.712762          -1
# 1              2    2    1            0  ...    0  58.565461          89
# 2              1    2    2            0  ...    1  76.432889          12
# 3              3    4    2            0  ...    1  87.351874          29
# 4              4    5    2            0  ...    0  75.440254          26
# ...          ...  ...  ...          ...  ...  ...        ...         ...
# 9995           3    3    2            0  ...    1  83.381334          22
# 9996           1    5    1            0  ...    0  49.631746          -1
# 9997           1    6    1            0  ...    0  53.602286          24
# 9998           1    3    2            0  ...    1  82.388699          26
# 9999           0    6    1            0  ...    0  43.675937          75
#
#       paracetamol  nad  corotrop  morphine  dve  atl  iot
# 0              -1   -1        -1        -1   -1   -1   25
# 1              58   26        -1        -1  116   -1   -1
# 2              -1   -1        -1        -1   40   -1   -1
# 3              -1   -1        -1        -1   -1   -1   53
# 4              -1   -1        -1        -1   79   -1   52
# ...           ...  ...       ...       ...  ...  ...  ...
# 9995           -1   -1        -1        -1   -1   -1   40
# 9996           -1   -1        -1        -1   24   -1   56
# 9997           -1   -1        -1        -1   -1   -1   55
# 9998           -1   -1        -1        -1   -1   -1   48
# 9999           46   -1        -1        -1   -1   -1   23
#
# [10000 rows x 31 columns]

# %%
size_train = int(len(df) * 0.8)

# %%
numerical = ['hospital_stay_length', 'gcs', 'nb_acte', 'age']
categorical = ['gender', 'entry', 'entry_code', 'ica', 'ttt', 'ica_therapy', 'fever', 'o2_clinic', 'o2', 'hta', 'hct', 'tabagisme', 'etOH', 'diabete', 'headache', 'instable', 'vasospasme', 'ivh']
events = ['nimodipine',  'paracetamol', 'nad', 'corotrop', 'morphine', 'dve', 'atl', 'iot']

events_codes = {
    'nimodipine': 'C08CA06', # ACT
    'paracetamol': 'N02BE01', # ACT
    'nad': 'C01CA03', # ACT
    'corotrop': 'C01CE02', # ACT
    'morphine': 'N02AA01', # ACT
    'dve': '00P6X0Z', # Removal of Drainage Device from Cerebral Ventricle External Approach (ICD-10)
    'atl': 'Z98.6', # ICD-10
    'iot': '0BH17EZ' # ICD-10
}

# %%
prefix  = """   
@prefix sphn: <http://sphn.org/> .
@prefix nvasc: <http://nvasc.org/> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
"""

sphn_diagnosis_code_date_template = Template("""
    nvasc:$diag_id a sphn:Diagnosis ;
        rdfs:label "$diag_label"^^xsd:string ;
        sphn:hasCode "$diag_code"^^xsd:string ;
        sphn:hasRecordDateTime "$diag_date"^^xsd:dateTime ;
        sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_$patient_id .
    """)

sphn_diagnosis_code_template = Template("""
    nvasc:$diag_id a sphn:Diagnosis ;
        rdfs:label "$diag_label"^^xsd:string ;
        sphn:hasCode "$diag_code"^^xsd:string ;
        sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_$patient_id .
    """)
    
sphn_diagnosis_quantity_template = Template("""
    nvasc:$diag_id a sphn:Diagnosis ;
        rdfs:label "$diag_label" ;
        sphn:hasQuantity [ rdf:type sphn:Quantity ;
                            sphn:hasValue "$diag_value" ;
                            sphn:hasUnit "$diag_unit" ] ;
        sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_$patient_id .
    """)

def gen_start_event(y_min=2020, y_max=2023):
    n_days = (y_max - y_min) * 365
    d0 = datetime.fromisoformat(f"{y_min}-01-01")
    day_rand = round(np.random.uniform(n_days))
    delta = timedelta(days=day_rand, hours=round(norm.rvs(12, 5)), minutes=round(np.random.uniform(60)))
    d_out = d0 + delta
    return(d_out)


def gen_patient_rdf(row, kg):
    _i = row.name
    d_start = gen_start_event()
    for f in row.index:
        if f in events:
            if row[f] != -1:    
                h = row[f]
                d_event = d_start + timedelta(hours=h)
                diag_label = f
                diag_code = events_codes[f]
                rdf = sphn_diagnosis_code_date_template.substitute(diag_id=uuid.uuid4(),
                                                        diag_label = f, 
                                                        diag_code = events_codes [f], 
                                                        diag_date = d_event.isoformat(),
                                                        patient_id = _i)
                print(row[f])
                print(d_start)
                print(rdf)
                kg.parse(data=prefix+rdf, format="turtle")
        
        elif f in numerical:
            value = None
            unit = None 
            if f == "hospital_stay_length":
                value = round(row[f])
                unit = "days"
            elif  f == "gcs":
                value = round(row[f],2)
                unit = "gcs"
            elif  f == "nb_acte":
                value = round(row[f])
                unit = "received medical treatments"
            elif  f == "age":
                value = round(row[f])
                unit = "age"
            
            rdf = sphn_diagnosis_quantity_template.substitute(
                diag_id=uuid.uuid4(),
                diag_label=f,  
                diag_value=value, 
                diag_unit=unit, 
                patient_id=_i)
            kg.parse(data=prefix+rdf, format="turtle")
            
        # ['gender', 'entry', 'entry_code', 'ica', 'ttt', 'ica_therapy', 'fever', 'o2_clinic', 'o2', 'hta', 'hct', 'tabagisme', 'etOH', 'diabete', 'headache', 'instable', 'vasospasme', 'ivh']
        elif f in categorical:
             diag_label = f
             diag_code = row[f]
             rdf = sphn_diagnosis_code_template.substitute(diag_id=uuid.uuid4(),
                                                     diag_label=f, 
                                                     diag_code=row[f], 
                                                     patient_id=_i)
        
             kg.parse(data=prefix+rdf, format="turtle")

# %%
date_entrance = gen_start_event()
print(date_entrance)
date_2 = date_entrance + timedelta(hours=36)
print(date_2)
# Out:
# 2020-03-06 14:24:00
# 2020-03-08 02:24:00

# %%
kg = ConjunctiveGraph()
test_df = df.head(100)
# print(test_df)
test_df.apply(gen_patient_rdf, axis=1, kg = kg)
print(f"Generated {len(kg)} RDF triples")
kg.serialize("sphn.ttl", format="turtle")
kg.serialize("sphn.nt", format="nt")
# Out:
# 25.0
# 2022-03-15 06:22:00
#
#     nvasc:7cdb48bf-8227-4ef7-8376-21c1d8587398 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-16T07:22:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_0 .
#
# 89.0
# 2022-11-22 15:23:00
#
#     nvasc:98f647b1-cf0e-41b6-a446-c1250e8dcd8f a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-26T08:23:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_1 .
#
# 58.0
# 2022-11-22 15:23:00
#
#     nvasc:a7eeb499-6c4b-471f-9386-9d1c67ae4022 a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-25T01:23:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_1 .
#
# 26.0
# 2022-11-22 15:23:00
#
#     nvasc:1b3ebd72-bcde-427a-ae15-9eabfe319ffc a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-23T17:23:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_1 .
#
# 116.0
# 2022-11-22 15:23:00
#
#     nvasc:0f568822-76db-4fc8-98c1-c7964dc92226 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-27T11:23:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_1 .
#
# 12.0
# 2022-08-12 00:45:00
#
#     nvasc:2e7226eb-9765-49eb-a52f-4e91e4b0d6db a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-08-12T12:45:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_2 .
#
# 40.0
# 2022-08-12 00:45:00
#
#     nvasc:db857362-df34-4188-affd-79dd5df65e3f a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-08-13T16:45:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_2 .
#
# 29.0
# 2020-08-18 13:49:00
#
#     nvasc:2e36de25-943a-4202-9e35-5fc7b17c1691 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-08-19T18:49:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_3 .
#
# 53.0
# 2020-08-18 13:49:00
#
#     nvasc:989d7229-409b-4d4e-a0dc-d8db315711fa a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-08-20T18:49:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_3 .
#
# 26.0
# 2022-03-20 04:08:00
#
#     nvasc:165a284c-2346-47dc-95dc-dd9017b43a86 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-21T06:08:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_4 .
#
# 79.0
# 2022-03-20 04:08:00
#
#     nvasc:b621417d-e8b8-4fab-b9ad-77ea8c2096e6 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-23T11:08:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_4 .
#
# 52.0
# 2022-03-20 04:08:00
#
#     nvasc:41aec324-6f9e-438c-8531-9d30148168aa a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-22T08:08:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_4 .
#
# 23.0
# 2020-11-08 12:44:00
#
#     nvasc:408eae93-21ed-42b2-9335-a9c7cca4c9c5 a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-09T11:44:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_5 .
#
# 26.0
# 2020-10-28 12:09:00
#
#     nvasc:bbef8ad3-1376-4460-9fb0-dcf2dde82a70 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-10-29T14:09:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_6 .
#
# 46.0
# 2020-10-28 12:09:00
#
#     nvasc:9303ec1f-521a-41e7-92da-2aaf5a79dbe1 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-10-30T10:09:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_6 .
#
# 35.0
# 2021-09-23 15:22:00
#
#     nvasc:1b1a0654-b7ec-4e49-a72e-71433b0246d5 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-09-25T02:22:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_7 .
#
# 53.0
# 2021-09-23 15:22:00
#
#     nvasc:06e8eca0-7e12-4342-91c0-a2a4c1ecf599 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-09-25T20:22:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_7 .
#
# 29.0
# 2021-12-19 19:46:00
#
#     nvasc:00d98056-da88-4411-babb-409170f9b6ba a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-21T00:46:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_8 .
#
# 32.0
# 2020-05-22 16:03:00
#
#     nvasc:81669a09-6519-41b2-86d8-923ae42a3fe9 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-24T00:03:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_9 .
#
# 25.0
# 2020-05-28 09:06:00
#
#     nvasc:094f9e4b-f56c-40cf-8975-5a7ce5b1aa71 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-29T10:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_10 .
#
# 71.0
# 2020-05-28 09:06:00
#
#     nvasc:6ec9228f-0899-4800-b197-2fd309325520 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-31T08:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_10 .
#
# 88.0
# 2020-05-28 09:06:00
#
#     nvasc:fc3b41ca-b5a7-4776-ac18-50c4b5266158 a sphn:Diagnosis ;
#         rdfs:label "atl"^^xsd:string ;
#         sphn:hasCode "Z98.6"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-01T01:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_10 .
#
# 47.0
# 2020-05-28 09:06:00
#
#     nvasc:e89539b6-412f-40f7-bde0-334b92f3fc0c a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-30T08:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_10 .
#
# 22.0
# 2022-12-31 05:57:00
#
#     nvasc:4d4baf63-a438-4797-a7e4-5490f3f61244 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2023-01-01T03:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_11 .
#
# 42.0
# 2022-12-31 05:57:00
#
#     nvasc:978ce8aa-2212-463e-97c0-643bd983bf4c a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2023-01-01T23:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_11 .
#
# 62.0
# 2022-12-31 05:57:00
#
#     nvasc:d4638022-aa27-456f-9323-f666f6fa90ee a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2023-01-02T19:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_11 .
#
# 67.0
# 2022-04-10 10:14:00
#
#     nvasc:02d2837a-efc4-442b-8c2b-14eb1279e9cc a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-04-13T05:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_12 .
#
# 38.0
# 2022-04-10 10:14:00
#
#     nvasc:b1113717-1156-4114-bbc7-bdcd02e469ee a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-04-12T00:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_12 .
#
# 91.0
# 2022-04-10 10:14:00
#
#     nvasc:420f45f0-1c62-4e65-9e8a-38a12b2fb2a7 a sphn:Diagnosis ;
#         rdfs:label "morphine"^^xsd:string ;
#         sphn:hasCode "N02AA01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-04-14T05:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_12 .
#
# 26.0
# 2022-04-10 10:14:00
#
#     nvasc:59a9ae2f-d39b-4415-bd7d-4a1832920d73 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-04-11T12:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_12 .
#
# 47.0
# 2022-01-23 06:04:00
#
#     nvasc:552a6b5b-86ed-48ed-aad4-177a7d4b3481 a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-01-25T05:04:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_13 .
#
# 28.0
# 2022-01-23 06:04:00
#
#     nvasc:c20e9065-d92c-4ce1-a3e8-68d6fb1ce1df a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-01-24T10:04:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_13 .
#
# 66.0
# 2022-01-23 06:04:00
#
#     nvasc:42b2a898-2032-4bdb-b167-a386f400e4d3 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-01-26T00:04:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_13 .
#
# 24.0
# 2021-11-27 17:19:00
#
#     nvasc:3208e341-5c26-4997-a7b0-abe4b37f5b32 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-11-28T17:19:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_14 .
#
# 21.0
# 2020-05-12 17:41:00
#
#     nvasc:dcb14df7-3445-4306-b732-d3dc645bdca5 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-13T14:41:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_15 .
#
# 48.0
# 2020-05-12 17:41:00
#
#     nvasc:e0182c75-2fb4-458d-ad3a-374c68811ecc a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-05-14T17:41:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_15 .
#
# 55.0
# 2021-08-08 07:10:00
#
#     nvasc:e4290745-afb5-4393-a951-6b803357c5ad a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-08-10T14:10:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_16 .
#
# 25.0
# 2021-08-08 07:10:00
#
#     nvasc:36ed3bb2-6905-492d-b190-a7568e3600bf a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-08
00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_48 .
#
# 67.0
# 2021-01-05 12:20:00
#
#     nvasc:4824983b-151b-488e-9bc9-15fdd3143b50 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-01-08T07:20:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_49 .
#
# 44.0
# 2021-01-05 12:20:00
#
#     nvasc:3fc8078b-08db-47db-8d9d-3381b4b6d8f5 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-01-07T08:20:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_49 .
#
# 20.0
# 2021-01-05 12:20:00
#
#     nvasc:852748f0-2bbc-41e7-9a5a-8298083b3b83 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-01-06T08:20:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_49 .
#
# 28.0
# 2021-08-08 09:09:00
#
#     nvasc:8f9da81b-353c-4309-947a-674dc61fee3e a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-08-09T13:09:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_50 .
#
# 25.0
# 2020-06-03 16:38:00
#
#     nvasc:42134454-89e6-4b3b-931e-6e112ffe55d9 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-04T17:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_51 .
#
# 90.0
# 2020-06-03 16:38:00
#
#     nvasc:5f042156-745c-462b-93ec-56481fad0f4e a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-07T10:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_51 .
#
# 62.0
# 2020-06-03 16:38:00
#
#     nvasc:fdc7ec3e-850f-4e54-bfe4-eef1bcc0703f a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-06T06:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_51 .
#
# 45.0
# 2020-06-03 16:38:00
#
#     nvasc:2f248e36-1377-4dd0-ac09-37c4ec607d1b a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-05T13:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_51 .
#
# 22.0
# 2020-12-14 13:28:00
#
#     nvasc:9342ca8b-88d5-4b45-ac59-c437ad69fd48 a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-12-15T11:28:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_52 .
#
# 23.0
# 2021-07-14 11:57:00
#
#     nvasc:e470c19e-a4ce-4bcb-af2b-6b7468dea710 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-07-15T10:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_53 .
#
# 47.0
# 2021-07-14 11:57:00
#
#     nvasc:172a74e5-f429-4560-9356-5fa0d4c97dea a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-07-16T10:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_53 .
#
# 18.0
# 2020-01-27 12:57:00
#
#     nvasc:755323a8-ae76-4ec0-9f9d-ad0ce692d464 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-28T06:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_54 .
#
# 42.0
# 2020-01-27 12:57:00
#
#     nvasc:2652150a-acdd-4443-bd5f-e077efbfd3cb a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-29T06:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_54 .
#
# 90.0
# 2020-01-27 12:57:00
#
#     nvasc:b146ff99-892d-44ee-8b9c-ae56be2be99d a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-31T06:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_54 .
#
# 68.0
# 2020-01-27 12:57:00
#
#     nvasc:127de3c1-9339-4d1d-968b-1d224b7df311 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-30T08:57:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_54 .
#
# 46.0
# 2022-11-17 04:38:00
#
#     nvasc:ef79b425-227a-41a5-bd32-a3c7e6788eb0 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-19T02:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_55 .
#
# 17.0
# 2022-11-17 04:38:00
#
#     nvasc:9bef9c4c-33b0-4d39-82ab-4bf1c11556ac a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-11-17T21:38:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_55 .
#
# 25.0
# 2020-02-14 13:07:00
#
#     nvasc:6cb65661-5211-4e5c-9066-13b5ed0faac8 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-02-15T14:07:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_56 .
#
# 43.0
# 2020-02-14 13:07:00
#
#     nvasc:30a4d8af-0610-4dc6-878a-c6b29924ad5e a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-02-16T08:07:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_56 .
#
# 70.0
# 2020-02-14 13:07:00
#
#     nvasc:0c08fac7-5bad-421d-8ffa-a1fe74c5a879 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-02-17T11:07:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_56 .
#
# 51.0
# 2022-12-19 08:05:00
#
#     nvasc:08f36cca-f5de-474f-81c2-ec5dd34e3a62 a sphn:Diagnosis ;
#         rdfs:label "corotrop"^^xsd:string ;
#         sphn:hasCode "C01CE02"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-12-21T11:05:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_57 .
#
# 23.0
# 2022-12-19 08:05:00
#
#     nvasc:410ddd31-7316-48a6-9329-73b298dc370d a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-12-20T07:05:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_57 .
#
# 64.0
# 2020-08-12 18:02:00
#
#     nvasc:b4f83107-df2c-4959-ac80-320e28125e46 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-08-15T10:02:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_58 .
#
# 44.0
# 2020-08-12 18:02:00
#
#     nvasc:0d23fbbe-f8a7-4dc6-8a62-b9fdaa8fe410 a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-08-14T14:02:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_58 .
#
# 23.0
# 2020-08-12 18:02:00
#
#     nvasc:95c03a79-b2ec-4a35-94a1-1cc412de3227 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-08-13T17:02:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_58 .
#
# 31.0
# 2022-03-19 08:32:00
#
#     nvasc:e399e457-ad88-4c71-bbb9-799bc17eba9c a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-20T15:32:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_59 .
#
# 69.0
# 2022-03-19 08:32:00
#
#     nvasc:627d8723-70bf-4ce9-9c03-608196df8762 a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-22T05:32:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_59 .
#
# 49.0
# 2022-03-19 08:32:00
#
#     nvasc:a5c8f399-60a4-4519-ade8-7fc7ecc19086 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-03-21T09:32:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_59 .
#
# 23.0
# 2022-07-08 08:14:00
#
#     nvasc:05ce5c8f-7a6b-4e8b-9573-dca9d8a06daa a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-07-09T07:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_60 .
#
# 49.0
# 2022-07-08 08:14:00
#
#     nvasc:47e51826-74e5-4dd9-ae98-807cb1206275 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-07-10T09:14:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_60 .
#
# 20.0
# 2022-10-24 09:13:00
#
#     nvasc:d03b5f35-e356-4966-a990-8138ec3443a1 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-10-25T05:13:00"^^xsd:dateTime ;
# ...
#
# 79.0
# 2022-08-06 03:22:00
#
#     nvasc:ecac54a4-01d9-47e4-a86d-070448a40e7f a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-08-09T10:22:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_80 .
#
# 55.0
# 2022-08-06 03:22:00
#
#     nvasc:f121bea8-5596-4b0b-8db9-1474c02f3b43 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-08-08T10:22:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_80 .
#
# 28.0
# 2020-11-16 11:06:00
#
#     nvasc:3904152c-0a31-4610-a34a-665320a7bec9 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-17T15:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_81 .
#
# 73.0
# 2020-11-16 11:06:00
#
#     nvasc:b499d663-0f3c-4c22-b426-d35a68ee4288 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-19T12:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_81 .
#
# 54.0
# 2020-11-16 11:06:00
#
#     nvasc:76c13aa1-f0a2-490d-be1d-86bb42065a7d a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-18T17:06:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_81 .
#
# 15.0
# 2020-01-17 17:24:00
#
#     nvasc:b17c76a3-9636-4c0d-a2de-7941e8fec34d a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-18T08:24:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_82 .
#
# 85.0
# 2020-03-05 20:43:00
#
#     nvasc:cdc90583-953b-4e6b-9700-7075c74bb66f a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-03-09T09:43:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_83 .
#
# 58.0
# 2020-03-05 20:43:00
#
#     nvasc:ca6ba509-3bfb-460f-9931-9e5e2adb7bba a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-03-08T06:43:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_83 .
#
# 29.0
# 2020-03-05 20:43:00
#
#     nvasc:ef20d121-5b2e-4cb4-999b-14e1b19fdf3c a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-03-07T01:43:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_83 .
#
# 16.0
# 2020-06-13 18:24:00
#
#     nvasc:194763da-9e91-4014-9604-dbd0bde75979 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-14T10:24:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_84 .
#
# 54.0
# 2020-06-13 18:24:00
#
#     nvasc:88a9582a-f99a-47ec-a8e0-f5ff97b6e15a a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-16T00:24:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_84 .
#
# 36.0
# 2020-06-13 18:24:00
#
#     nvasc:537941fc-861c-43cb-9dd8-5e001625bc4a a sphn:Diagnosis ;
#         rdfs:label "morphine"^^xsd:string ;
#         sphn:hasCode "N02AA01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-06-15T06:24:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_84 .
#
# 25.0
# 2022-12-27 13:48:00
#
#     nvasc:135f4537-6fce-4ba4-af73-0e6670ce108e a sphn:Diagnosis ;
#         rdfs:label "morphine"^^xsd:string ;
#         sphn:hasCode "N02AA01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-12-28T14:48:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_85 .
#
# 22.0
# 2021-12-05 10:34:00
#
#     nvasc:071f39cb-21e8-462c-9d38-16d91b9d75ac a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-06T08:34:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_86 .
#
# 44.0
# 2021-12-05 10:34:00
#
#     nvasc:9301ed0d-ae4b-4a0b-8b9c-46980474fa9b a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-07T06:34:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_86 .
#
# 17.0
# 2022-09-12 15:51:00
#
#     nvasc:424af487-ce5d-4502-b942-4eddf1c3fe90 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-13T08:51:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_87 .
#
# 85.0
# 2022-09-12 15:51:00
#
#     nvasc:0383ddde-9d3d-4e1e-a5e1-464036602d0e a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-16T04:51:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_87 .
#
# 59.0
# 2022-09-12 15:51:00
#
#     nvasc:3d4043c7-aee2-4b47-ae87-1be0a7daf987 a sphn:Diagnosis ;
#         rdfs:label "morphine"^^xsd:string ;
#         sphn:hasCode "N02AA01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-15T02:51:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_87 .
#
# 39.0
# 2022-09-12 15:51:00
#
#     nvasc:e4830fc3-2917-4073-a698-54e4d1278068 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-14T06:51:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_87 .
#
# 113.0
# 2022-09-12 15:51:00
#
#     nvasc:cb220566-8b3b-4ead-8ede-1a7e85eea370 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-17T08:51:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_87 .
#
# 23.0
# 2020-03-21 11:53:00
#
#     nvasc:46ae4caf-c3cb-45e3-b3e9-78d202155c0b a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-03-22T10:53:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_88 .
#
# 28.0
# 2020-11-15 06:50:00
#
#     nvasc:6a580a54-5acf-46c8-83b4-6058e0df2f0a a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-16T10:50:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_89 .
#
# 72.0
# 2020-01-16 09:47:00
#
#     nvasc:eeba348b-953a-4d52-a6fb-5b583204cf12 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-19T09:47:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_90 .
#
# 54.0
# 2020-01-16 09:47:00
#
#     nvasc:433fed76-2b56-474e-91fd-743dc8b6d036 a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-18T15:47:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_90 .
#
# 21.0
# 2020-01-16 09:47:00
#
#     nvasc:fc1a1d4c-b348-439b-baa9-638334a2755d a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-01-17T06:47:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_90 .
#
# 69.0
# 2022-10-20 20:36:00
#
#     nvasc:d630dcb4-c8d3-4c2a-bdba-5e929ef0b0ad a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-10-23T17:36:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_91 .
#
# 88.0
# 2022-10-20 20:36:00
#
#     nvasc:d04a8882-78e9-4613-ad30-62e3fed3a20b a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-10-24T12:36:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_91 .
#
# 51.0
# 2022-10-20 20:36:00
#
#     nvasc:07a20f81-b360-46bb-b8f4-e50237055349 a sphn:Diagnosis ;
#         rdfs:label "morphine"^^xsd:string ;
#         sphn:hasCode "N02AA01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-10-22T23:36:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_91 .
#
# 27.0
# 2022-10-20 20:36:00
#
#     nvasc:a7e4e70c-823c-4f3d-bdc1-91fc2034803b a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-10-21T23:36:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_91 .
#
# 25.0
# 2022-09-20 12:32:00
#
#     nvasc:45dbf5ae-cc8b-4fba-b947-4bd77b4b44a8 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-21T13:32:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_92 .
#
# 44.0
# 2022-09-20 12:32:00
#
#     nvasc:83566d5e-2965-4b58-82b4-a25db990d4aa a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-09-22T08:32:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_92 .
#
# 29.0
# 2020-11-26 15:09:00
#
#     nvasc:2d8f7bb0-1f44-4ae2-beea-f25b2d5d5ff5 a sphn:Diagnosis ;
#         rdfs:label "atl"^^xsd:string ;
#         sphn:hasCode "Z98.6"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-11-27T20:09:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_93 .
#
# 25.0
# 2021-05-08 11:37:00
#
#     nvasc:d156f22e-ba3b-49a4-9831-4633b0366726 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-05-09T12:37:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_94 .
#
# 58.0
# 2021-05-08 11:37:00
#
#     nvasc:74042e22-4ca3-4c11-83e9-6a6ed4d05a2c a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-05-10T21:37:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_94 .
#
# 47.0
# 2021-12-14 13:25:00
#
#     nvasc:3fbc3f1d-f7d0-4f5d-a7fd-690ff1b2d380 a sphn:Diagnosis ;
#         rdfs:label "corotrop"^^xsd:string ;
#         sphn:hasCode "C01CE02"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-16T12:25:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_95 .
#
# 21.0
# 2021-12-14 13:25:00
#
#     nvasc:ec66e346-ebaa-498f-bf08-b9c9c3c51693 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-15T10:25:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_95 .
#
# 76.0
# 2021-12-14 13:25:00
#
#     nvasc:c25a3dfe-db4c-416c-aa21-21ba6f9ee1aa a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-12-17T17:25:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_95 .
#
# 104.0
# 2020-07-02 11:31:00
#
#     nvasc:2c0379a0-2b84-4d5f-9fc9-478d7c812f33 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-07-06T19:31:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_96 .
#
# 74.0
# 2020-07-02 11:31:00
#
#     nvasc:33b78898-105b-42c2-8488-025484fbf75e a sphn:Diagnosis ;
#         rdfs:label "nad"^^xsd:string ;
#         sphn:hasCode "C01CA03"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-07-05T13:31:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_96 .
#
# 54.0
# 2020-07-02 11:31:00
#
#     nvasc:d7a1a6db-0783-4a72-b078-dd94e2a29104 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-07-04T17:31:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_96 .
#
# 26.0
# 2020-07-02 11:31:00
#
#     nvasc:4cde6b31-345c-4cf2-b260-84204e3137e3 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2020-07-03T13:31:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_96 .
#
# 49.0
# 2022-06-08 15:13:00
#
#     nvasc:2ce59c17-c97f-4253-b631-b5696febc5e7 a sphn:Diagnosis ;
#         rdfs:label "nimodipine"^^xsd:string ;
#         sphn:hasCode "C08CA06"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-06-10T16:13:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_97 .
#
# 27.0
# 2022-06-08 15:13:00
#
#     nvasc:8ee5610a-211d-43aa-a6ee-dbaa6c644305 a sphn:Diagnosis ;
#         rdfs:label "paracetamol"^^xsd:string ;
#         sphn:hasCode "N02BE01"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-06-09T18:13:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_97 .
#
# 102.0
# 2022-06-08 15:13:00
#
#     nvasc:e9c82700-1c02-48c0-9028-0128cd35cca2 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-06-12T21:13:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_97 .
#
# 75.0
# 2022-06-08 15:13:00
#
#     nvasc:db85c3c3-1f32-4635-ba9c-ef395586619f a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2022-06-11T18:13:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_97 .
#
# 23.0
# 2021-10-06 09:37:00
#
#     nvasc:2316d524-19f1-4df7-8ecb-1cdf49ef08b9 a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-10-07T08:37:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_98 .
#
# 50.0
# 2021-10-06 09:37:00
#
#     nvasc:971dfae1-1b7a-4eb3-90c5-6c200727f3c8 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-10-08T11:37:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_98 .
#
# 21.0
# 2021-06-02 04:30:00
#
#     nvasc:ce90e0b8-f57f-48ea-a4d4-ffd39f9f5a3c a sphn:Diagnosis ;
#         rdfs:label "dve"^^xsd:string ;
#         sphn:hasCode "00P6X0Z"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-06-03T01:30:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_99 .
#
# 47.0
# 2021-06-02 04:30:00
#
#     nvasc:44765611-f7e5-4491-b651-d2312a0cc524 a sphn:Diagnosis ;
#         rdfs:label "iot"^^xsd:string ;
#         sphn:hasCode "0BH17EZ"^^xsd:string ;
#         sphn:hasRecordDateTime "2021-06-04T03:30:00"^^xsd:dateTime ;
#         sphn:hasSubjectPseudoIdentifier nvasc:synth_patient_99 .
#
# Generated 11205 RDF triples
# /Users/gaignard-a/miniconda3/envs/neurovasc-clinpath/lib/python3.10/site-packages/rdflib/plugins/serializers/nt.py:40: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: None
#   warnings.warn(
# <Graph identifier=Nd62df61d1a2c4fcaaeedf130fbc7aa02 (<class 'rdflib.graph.ConjunctiveGraph'>)>

# %% [markdown]
# # Computing the duration of care events

# %%
## Understanding this code ... 
events = ['nimodipine',  'paracetamol', 'nad', 'corotrop', 'morphine', 'dve', 'atl', 'iot']
events_end = events + ['finish']

transitions = pd.read_csv('./care_transitions_probs.csv', index_col=0)
transitions

start_probs = [0.47381546, 0.09476309, 0.00997506, 0, 0.00997506, 0.24189526, 0.00249377, 0.16708229, 0]

# Generate a sequence of care events 
# The sequence is generated by starting with an initial event and then randomly selecting the next event based on the transition probabilities
def generate_care_path():
    event = np.random.choice(events_end, size=1, p=start_probs)[0]
    path = [event]

    while event != 'finish':
        event = np.random.choice(events_end, size=1, p=transitions[event].values)[0]
        # ensure that their is no duplicate event
        if event in path:
            event = 'finish'
        path += [event]
        
    # remove the finish event and return the path
    return path[:-1]
    

def generate_times_path(path):
    # Generate the time taken (in hour) for each event with a normal distribution with parameters mean=24 and std=5
    indv_times = map(round, norm.rvs(24, 5, len(path)))
    acc_times = list(accumulate(indv_times))
    # print(list(acc_times))

    sol = [-1] * len(events)
    # print(sol)
    for i, e in enumerate(path):
        sol[events.index(e)] = acc_times[i]
    
    # print(sol)
    return sol

# %%
generate_care_path()
# Out:
# ['dve', 'nad', 'paracetamol', 'nimodipine']

# %%
df_events = pd.DataFrame([generate_times_path(generate_care_path()) for _ in range(5)], columns=events)
df_events
# Out:
#    nimodipine  paracetamol  nad  corotrop  morphine  dve  atl  iot
# 0          24           -1   -1        -1        -1   -1   -1   -1
# 1          24           50   -1        -1        -1   -1   -1   -1
# 2          -1           -1   -1        -1        -1   18   -1   -1
# 3          -1           -1   -1        50        -1   22   -1   62
# 4          29           -1   -1        -1        -1   70   -1   46
